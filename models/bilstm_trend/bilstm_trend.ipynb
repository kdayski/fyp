# %% [markdown]
# # BiLSTM Model for predicting trend

# %%
#imports
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
import joblib 

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat


import keras.utils
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
"""
method to create lagged features

data - data
to_keep - number of lagged_features
to_remove - number of days to remove

"""
def create_lagged_features(data, to_keep=1, to_remove=1):
    variables = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    columns, names = list(), list()
    
    for i in range(to_keep, 0, -1):
        columns.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(variables)]

    for i in range(0, to_remove):
        columns.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(variables)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(variables)]
            
    #put it all together
    final = concat(columns, axis=1)
    final.columns = names
    
    #drop rows with NaN values
    final.dropna(inplace=True)
        
    return final

# %%
"""
function to calculate rsi

data - data
period - RSI period

"""
def rsi(data, period: int = 14):
    
    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity - days or hours
lag_granularity = "days"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "day"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/"+analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_"+str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename)

# %%
# Нерабочий исходный код
#group by datetime
# df = df.groupby('DateTime').agg(lambda x: x.mean())

# Convert the 'DateTime' column to datetime format
df['DateTime'] = pd.to_datetime(df['DateTime'])

# Exclude non-numeric columns ('DateTime' and 'dt') from the aggregation
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Perform the aggregation on numeric columns only, grouping by 'DateTime'
df_grouped = df.groupby('DateTime')[numeric_columns].mean()

# Reset the index if you want 'DateTime' back as a column
df_grouped.reset_index(inplace=True)

# Now df_grouped contains the mean of numeric columns, grouped by 'DateTime'

# %%
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = False
add_longMAvg = False
add_shortMAvg = False

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()
    
if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()
    
if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity','Tweet_vol','Volume_(BTC)'] if analyser == "Textblob" else ['Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")
    
if(add_longMAvg):
    features.append("long_mavg")
    
if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
#add lagged data to records
data_with_lagged = create_lagged_features(df_copy, n_lag, 1)
# Check the column names of the DataFrame after creating lagged features

data_with_lagged = data_with_lagged.reset_index()

# Нерабочий исходный код
# data_with_lagged = data_with_lagged.drop(['DateTime'], axis=1)

data_with_lagged = data_with_lagged.drop(['index'], axis=1)

# %%
#shuffle data
np.random.seed(1)
#shuffle times 
shuffle_times = 5;
for j in range(0, shuffle_times+1):
    data_with_lagged = shuffle(data_with_lagged)

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)
train = data_with_lagged.iloc[:train_size]
test = data_with_lagged.iloc[train_size:]
print(data_with_lagged)
data_with_lagged.to_csv("saved/data_with_lagged.csv")
# Out:
#      var1(t-7)  var2(t-7)  var3(t-7)  var4(t-7)  var5(t-7)  var1(t-6)  \
# 338        1.0   10970.33   0.193839   0.058179    58958.0        1.0
# 354        1.0   10784.86   0.181155   0.069138    64375.0        0.0
# 389        0.0    8650.00   0.184604   0.063351    66469.0        0.0
# 420        1.0    8600.29   0.181854   0.074674    71917.0        1.0
# 311        1.0   12347.17   0.184391   0.065712    57548.0        1.0
# ..         ...        ...        ...        ...        ...        ...
# 409        1.0    8311.99   0.187424   0.060773    49669.0        0.0
# 436        1.0    9080.00   0.178325   0.068825    43645.0        0.0
# 203        1.0    3983.90   0.169404   0.040888      925.0        0.0
# 235        1.0    5567.39   0.154252   0.044981     1029.0        0.0
# 85         0.0    3700.06   0.116214   0.044069      903.0        1.0
#
#      var2(t-6)  var3(t-6)  var4(t-6)  var5(t-6)  ...  var1(t-1)  var2(t-1)  \
# 338   11730.00   0.191035   0.061125    57470.0  ...        0.0   11289.00
# 354   10046.47   0.178628   0.076397    68567.0  ...        1.0   10254.95
# 389    8580.00   0.175963   0.081008    81359.0  ...        1.0    8253.08
# 420    9250.00   0.178646   0.075265    74341.0  ...        0.0    9127.50
# 311   12562.12   0.178387   0.070697    72603.0  ...        0.0   10637.40
# ..         ...        ...        ...        ...  ...        ...        ...
# 409    8150.21   0.182246   0.063615    56389.0  ...        1.0    8212.40
# 436    8709.30   0.177422   0.066089    50808.0  ...        0.0    8469.20
# 203    3976.00   0.165148   0.036593      881.0  ...        0.0    4010.35
# 235    5437.80   0.166830   0.044038     1121.0  ...        0.0    5130.24
# 85     3953.81   0.119378   0.046616      933.0  ...        0.0    3941.85
#
#      var3(t-1)  var4(t-1)  var5(t-1)  var1(t)   var2(t)   var3(t)   var4(t)  \
# 338   0.179227   0.076865    67931.0        1  11505.03  0.200654  0.067783
# 354   0.188167   0.064011    54485.0        0  10135.34  0.180847  0.068994
# 389   0.184744   0.068079    50258.0        1   8318.26  0.172751  0.072454
# 420   0.179494   0.067002    59961.0        1   9204.47  0.188142  0.063351
# 311   0.178475   0.074586    70130.0        1  10737.18  0.172561  0.074977
# ..         ...        ...        ...      ...       ...       ...       ...
# 409   0.180183   0.070314    51224.0        1   8214.63  0.183766  0.064176
# 436   0.176000   0.070255    56993.0        1   8545.36  0.178359  0.070595
# 203   0.154529   0.049106      955.0        1   4079.26  0.176996  0.064060
# 235   0.166141   0.042350      957.0        1   5256.33  0.174962  0.040538
# 85    0.176877   0.070639    42841.0        1   4174.28  0.115017  0.053267
#
#      var5(t)
# 338  62379.0
# 354  65367.0
# 389  60580.0
# 420  62621.0
# 311  66456.0
# ..       ...
# 409  50095.0
# 436  46589.0
# 203   3464.0
# 235   1177.0
# 85     943.0
#
# [444 rows x 40 columns]

# %%
#prepare labels
train_y = train["var1(t)"].values
test_y = test["var1(t)"].values

train_y = train_y.reshape(len(train_y), 1)
test_y = test_y.reshape(len(test_y), 1)

# %%
#normalise features
xscaler = MinMaxScaler(feature_range=(0, 1))
train = xscaler.fit_transform(train)
test = xscaler.transform(test)
joblib.dump(xscaler, 'saved/scaler.pkl')
# Out:
# ['saved/scaler.pkl']

# %%
#prepare data
train_labels = train_y
test_labels = test_y

# %%
#remove the last set of values(data of time to be predicted)
train = train[:, :total_features]
test = test[:, :total_features]

# %%
#keep only prices array
train_X, train_y = train[:, :total_features], train_y[:, -1]
test_X, test_y = test[:, :total_features], test_y[:, -1]

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_lag, n_features))
test_X = test_X.reshape((test_X.shape[0], n_lag, n_features))

# %%
#set labels for training data to categorical
train_y = keras.utils.to_categorical(train_y, 2)

# %%
np.random.seed(1) 
tf.random.set_seed(1)

# design network
model = Sequential()
neurons = 64
epochs = 10000
dropout = 0.25
batch_size = 80
activ_func = "linear"

model.add(Bidirectional(LSTM(neurons, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2]), activation=activ_func)))
model.add(Dropout(dropout))

model.add(Bidirectional(LSTM(neurons, return_sequences=False, activation=activ_func)))
model.add(Dropout(dropout))

model.add(Dense(2, activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# early stopping
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =50)

# fit network
history = model.fit(train_X, train_y, epochs=10000, batch_size=batch_size, verbose=2, shuffle=True,validation_split=0.2, callbacks=[callback])
# Out:
# Epoch 1/10000
# 4/4 - 4s - loss: 0.6946 - accuracy: 0.4817 - val_loss: 0.6868 - val_accuracy: 0.5526 - 4s/epoch - 954ms/step
# Epoch 2/10000
# 4/4 - 0s - loss: 0.6895 - accuracy: 0.5349 - val_loss: 0.6848 - val_accuracy: 0.5526 - 51ms/epoch - 13ms/step
# Epoch 3/10000
# 4/4 - 0s - loss: 0.6951 - accuracy: 0.5316 - val_loss: 0.6835 - val_accuracy: 0.5526 - 50ms/epoch - 12ms/step
# Epoch 4/10000
# 4/4 - 0s - loss: 0.6893 - accuracy: 0.5282 - val_loss: 0.6827 - val_accuracy: 0.5526 - 49ms/epoch - 12ms/step
# Epoch 5/10000
# 4/4 - 0s - loss: 0.6882 - accuracy: 0.5116 - val_loss: 0.6842 - val_accuracy: 0.6053 - 48ms/epoch - 12ms/step
# Epoch 6/10000
# 4/4 - 0s - loss: 0.6896 - accuracy: 0.5183 - val_loss: 0.6821 - val_accuracy: 0.5921 - 49ms/epoch - 12ms/step
# Epoch 7/10000
# 4/4 - 0s - loss: 0.6887 - accuracy: 0.5282 - val_loss: 0.6807 - val_accuracy: 0.5526 - 52ms/epoch - 13ms/step
# Epoch 8/10000
# 4/4 - 0s - loss: 0.6842 - accuracy: 0.5449 - val_loss: 0.6812 - val_accuracy: 0.5789 - 52ms/epoch - 13ms/step
# Epoch 9/10000
# 4/4 - 0s - loss: 0.6856 - accuracy: 0.5282 - val_loss: 0.6825 - val_accuracy: 0.5395 - 51ms/epoch - 13ms/step
# Epoch 10/10000
# 4/4 - 0s - loss: 0.6885 - accuracy: 0.5349 - val_loss: 0.6798 - val_accuracy: 0.5921 - 53ms/epoch - 13ms/step
# Epoch 11/10000
# 4/4 - 0s - loss: 0.6809 - accuracy: 0.5648 - val_loss: 0.6781 - val_accuracy: 0.5526 - 52ms/epoch - 13ms/step
# Epoch 12/10000
# 4/4 - 0s - loss: 0.6823 - accuracy: 0.5515 - val_loss: 0.6770 - val_accuracy: 0.6053 - 50ms/epoch - 13ms/step
# Epoch 13/10000
# 4/4 - 0s - loss: 0.6824 - accuracy: 0.5581 - val_loss: 0.6783 - val_accuracy: 0.5658 - 50ms/epoch - 12ms/step
# Epoch 14/10000
# 4/4 - 0s - loss: 0.6781 - accuracy: 0.5482 - val_loss: 0.6821 - val_accuracy: 0.5395 - 50ms/epoch - 13ms/step
# Epoch 15/10000
# 4/4 - 0s - loss: 0.6794 - accuracy: 0.5615 - val_loss: 0.6788 - val_accuracy: 0.5526 - 50ms/epoch - 13ms/step
# Epoch 16/10000
# 4/4 - 0s - loss: 0.6814 - accuracy: 0.5615 - val_loss: 0.6769 - val_accuracy: 0.5658 - 53ms/epoch - 13ms/step
# Epoch 17/10000
# 4/4 - 0s - loss: 0.6784 - accuracy: 0.5648 - val_loss: 0.6762 - val_accuracy: 0.5658 - 50ms/epoch - 12ms/step
# Epoch 18/10000
# 4/4 - 0s - loss: 0.6826 - accuracy: 0.5482 - val_loss: 0.6777 - val_accuracy: 0.5132 - 49ms/epoch - 12ms/step
# Epoch 19/10000
# 4/4 - 0s - loss: 0.6762 - accuracy: 0.5615 - val_loss: 0.6763 - val_accuracy: 0.5526 - 49ms/epoch - 12ms/step
# Epoch 20/10000
# 4/4 - 0s - loss: 0.6774 - accuracy: 0.5880 - val_loss: 0.6774 - val_accuracy: 0.5132 - 48ms/epoch - 12ms/step
# Epoch 21/10000
# 4/4 - 0s - loss: 0.6737 - accuracy: 0.5814 - val_loss: 0.6794 - val_accuracy: 0.5921 - 50ms/epoch - 13ms/step
# Epoch 22/10000
# 4/4 - 0s - loss: 0.6748 - accuracy: 0.5482 - val_loss: 0.6780 - val_accuracy: 0.5132 - 51ms/epoch - 13ms/step
# Epoch 23/10000
# 4/4 - 0s - loss: 0.6763 - accuracy: 0.5714 - val_loss: 0.6801 - val_accuracy: 0.5526 - 48ms/epoch - 12ms/step
# Epoch 24/10000
# 4/4 - 0s - loss: 0.6724 - accuracy: 0.5748 - val_loss: 0.6789 - val_accuracy: 0.5132 - 49ms/epoch - 12ms/step
# Epoch 25/10000
# 4/4 - 0s - loss: 0.6735 - accuracy: 0.5515 - val_loss: 0.6802 - val_accuracy: 0.5000 - 48ms/epoch - 12ms/step
# Epoch 26/10000
# 4/4 - 0s - loss: 0.6734 - accuracy: 0.5615 - val_loss: 0.6811 - val_accuracy: 0.5526 - 48ms/epoch - 12ms/step
# Epoch 27/10000
# 4/4 - 0s - loss: 0.6694 - accuracy: 0.5947 - val_loss: 0.6815 - val_accuracy: 0.5526 - 48ms/epoch - 12ms/step
# Epoch 28/10000
# 4/4 - 0s - loss: 0.6727 - accuracy: 0.5814 - val_loss: 0.6831 - val_accuracy: 0.5526 - 48ms/epoch - 12ms/step
# Epoch 29/10000
# 4/4 - 0s - loss: 0.6688 - accuracy: 0.5781 - val_loss: 0.6846 - val_accuracy: 0.5789 - 48ms/epoch - 12ms/step
# Epoch 30/10000
# 4/4 - 0s - loss: 0.6650 - accuracy: 0.6080 - val_loss: 0.6863 - val_accuracy: 0.5395 - 49ms/epoch - 12ms/step
# Epoch 31/10000
# 4/4 - 0s - loss: 0.6725 - accuracy: 0.5615 - val_loss: 0.6893 - val_accuracy: 0.5789 - 50ms/epoch - 13ms/step
# Epoch 32/10000
# 4/4 - 0s - loss: 0.6737 - accuracy: 0.5615 - val_loss: 0.6873 - val_accuracy: 0.5395 - 51ms/epoch - 13ms/step
# Epoch 33/10000
# 4/4 - 0s - loss: 0.6659 - accuracy: 0.5880 - val_loss: 0.6872 - val_accuracy: 0.5526 - 50ms/epoch - 12ms/step
# Epoch 34/10000
# 4/4 - 0s - loss: 0.6586 - accuracy: 0.6047 - val_loss: 0.6926 - val_accuracy: 0.5921 - 49ms/epoch - 12ms/step
# Epoch 35/10000
# 4/4 - 0s - loss: 0.6617 - accuracy: 0.5748 - val_loss: 0.6904 - val_accuracy: 0.5789 - 48ms/epoch - 12ms/step
# Epoch 36/10000
# 4/4 - 0s - loss: 0.6693 - accuracy: 0.6179 - val_loss: 0.6928 - val_accuracy: 0.5789 - 48ms/epoch - 12ms/step
# Epoch 37/10000
# 4/4 - 0s - loss: 0.6670 - accuracy: 0.6013 - val_loss: 0.6919 - val_accuracy: 0.5658 - 48ms/epoch - 12ms/step
# Epoch 38/10000
# 4/4 - 0s - loss: 0.6579 - accuracy: 0.5847 - val_loss: 0.6956 - val_accuracy: 0.5395 - 48ms/epoch - 12ms/step
# Epoch 39/10000
# 4/4 - 0s - loss: 0.6600 - accuracy: 0.5714 - val_loss: 0.6934 - val_accuracy: 0.5658 - 48ms/epoch - 12ms/step
# Epoch 40/10000
# 4/4 - 0s - loss: 0.6557 - accuracy: 0.6213 - val_loss: 0.6979 - val_accuracy: 0.5526 - 49ms/epoch - 12ms/step
# Epoch 41/10000
# 4/4 - 0s - loss: 0.6582 - accuracy: 0.5914 - val_loss: 0.6998 - val_accuracy: 0.5395 - 49ms/epoch - 12ms/step
# Epoch 42/10000
# 4/4 - 0s - loss: 0.6718 - accuracy: 0.5681 - val_loss: 0.7046 - val_accuracy: 0.5395 - 48ms/epoch - 12ms/step
# Epoch 43/10000
# 4/4 - 0s - loss: 0.6512 - accuracy: 0.6047 - val_loss: 0.7043 - val_accuracy: 0.5263 - 49ms/epoch - 12ms/step
# Epoch 44/10000
# 4/4 - 0s - loss: 0.6603 - accuracy: 0.5880 - val_loss: 0.7053 - val_accuracy: 0.5658 - 49ms/epoch - 12ms/step
# Epoch 45/10000
# 4/4 - 0s - loss: 0.6748 - accuracy: 0.5714 - val_loss: 0.6994 - val_accuracy: 0.5526 - 49ms/epoch - 12ms/step
# Epoch 46/10000
# 4/4 - 0s - loss: 0.6511 - accuracy: 0.5947 - val_loss: 0.6996 - val_accuracy: 0.5395 - 49ms/epoch - 12ms/step
# Epoch 47/10000
# 4/4 - 0s - loss: 0.6636 - accuracy: 0.5947 - val_loss: 0.6965 - val_accuracy: 0.5263 - 49ms/epoch - 12ms/step
# Epoch 48/10000
# 4/4 - 0s - loss: 0.6553 - accuracy: 0.5847 - val_loss: 0.7049 - val_accuracy: 0.5789 - 49ms/epoch - 12ms/step
# Epoch 49/10000
# 4/4 - 0s - loss: 0.6584 - accuracy: 0.6080 - val_loss: 0.6984 - val_accuracy: 0.5263 - 49ms/epoch - 12ms/step
# Epoch 50/10000
# 4/4 - 0s - loss: 0.6535 - accuracy: 0.5880 - val_loss: 0.6959 - val_accuracy: 0.4737 - 49ms/epoch - 12ms/step
# Epoch 51/10000
# 4/4 - 0s - loss: 0.6555 - accuracy: 0.6013 - val_loss: 0.6983 - val_accuracy: 0.4868 - 48ms/epoch - 12ms/step
# Epoch 52/10000
# 4/4 - 0s - loss: 0.6567 - accuracy: 0.5748 - val_loss: 0.7048 - val_accuracy: 0.5263 - 48ms/epoch - 12ms/step
# Epoch 53/10000
# 4/4 - 0s - loss: 0.6554 - accuracy: 0.5681 - val_loss: 0.7009 - val_accuracy: 0.4605 - 49ms/epoch - 12ms/step
# Epoch 54/10000
# 4/4 - 0s - loss: 0.6536 - accuracy: 0.5714 - val_loss: 0.7052 - val_accuracy: 0.5132 - 48ms/epoch - 12ms/step
# Epoch 55/10000
# 4/4 - 0s - loss: 0.6521 - accuracy: 0.5548 - val_loss: 0.7161 - val_accuracy: 0.5263 - 49ms/epoch - 12ms/step
# Epoch 56/10000
# 4/4 - 0s - loss: 0.6503 - accuracy: 0.5980 - val_loss: 0.7123 - val_accuracy: 0.5132 - 49ms/epoch - 12ms/step
# Epoch 57/10000
# 4/4 - 0s - loss: 0.6635 - accuracy: 0.6080 - val_loss: 0.7097 - val_accuracy: 0.4868 - 49ms/epoch - 12ms/step
# Epoch 58/10000
# 4/4 - 0s - loss: 0.6578 - accuracy: 0.5980 - val_loss: 0.7158 - val_accuracy: 0.5921 - 49ms/epoch - 12ms/step
# Epoch 59/10000
# 4/4 - 0s - loss: 0.6544 - accuracy: 0.5781 - val_loss: 0.7122 - val_accuracy: 0.5132 - 49ms/epoch - 12ms/step
# Epoch 60/10000
# 4/4 - 0s - loss: 0.6512 - accuracy: 0.5748 - val_loss: 0.7032 - val_accuracy: 0.4737 - 48ms/epoch - 12ms/step
# Epoch 61/10000
# 4/4 - 0s - loss: 0.6567 - accuracy: 0.5880 - val_loss: 0.7047 - val_accuracy: 0.5000 - 48ms/epoch - 12ms/step
# Epoch 62/10000
# 4/4 - 0s - loss: 0.6543 - accuracy: 0.5914 - val_loss: 0.7085 - val_accuracy: 0.5000 - 49ms/epoch - 12ms/step
# Epoch 63/10000
# 4/4 - 0s - loss: 0.6521 - accuracy: 0.5681 - val_loss: 0.7139 - val_accuracy: 0.5789 - 48ms/epoch - 12ms/step
# Epoch 64/10000
# 4/4 - 0s - loss: 0.6522 - accuracy: 0.5847 - val_loss: 0.7065 - val_accuracy: 0.5000 - 48ms/epoch - 12ms/step
# Epoch 65/10000
# 4/4 - 0s - loss: 0.6516 - accuracy: 0.6179 - val_loss: 0.7118 - val_accuracy: 0.5395 - 48ms/epoch - 12ms/step
# Epoch 66/10000
# 4/4 - 0s - loss: 0.6625 - accuracy: 0.5648 - val_loss: 0.7118 - val_accuracy: 0.5526 - 48ms/epoch - 12ms/step
# Epoch 67/10000
# 4/4 - 0s - loss: 0.6501 - accuracy: 0.6080 - val_loss: 0.7086 - val_accuracy: 0.5263 - 48ms/epoch - 12ms/step

# %%
#save model
model.save("saved/ckpt")
model.save("saved/bilstm_model.h5")
# Out:
# c:\Users\igor\Desktop\fyp\fyp-env\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#save model
model_file = 'model.png'
tf.keras.utils.plot_model(model, to_file=model_file, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
#plot loss graph
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.title("Loss graph")
plt.show()

# %%
#plot training and validation accuracy
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,len(loss_val) + 1)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#reshape
test_X = test_X.reshape((test_X.shape[0], n_lag, n_features))

#predict values for test data
pred = model.predict(test_X)

#reshape again
test_X = test_X.reshape((test_X.shape[0], n_lag* n_features,))
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
#change back from categorical
pred = np.argmax(pred, axis=1)

# %%
#calculate accuracy
prices = pd.DataFrame()
prices["Actual"] = test_y
prices["Predicted"] = pred

prices["Correct"] = (prices["Actual"] - prices["Predicted"]) == 0
incorrect = prices.loc[prices['Correct'] == False]
incorrect_len = len(incorrect)
prices_len = len(prices)

print("Accuracy = ",((prices_len-incorrect_len)/prices_len))
# Out:
# Accuracy =  0.6268656716417911

# %%
sklearn.metrics.classification_report(test_y, pred, zero_division=0,output_dict=True)
# Out:
# {'0': {'precision': 0.7307692307692307,
#   'recall': 0.5135135135135135,
#   'f1-score': 0.6031746031746031,
#   'support': 37.0},
#  '1': {'precision': 0.5609756097560976,
#   'recall': 0.7666666666666667,
#   'f1-score': 0.647887323943662,
#   'support': 30.0},
#  'accuracy': 0.6268656716417911,
#  'macro avg': {'precision': 0.6458724202626642,
#   'recall': 0.6400900900900901,
#   'f1-score': 0.6255309635591326,
#   'support': 67.0},
#  'weighted avg': {'precision': 0.6547422362857382,
#   'recall': 0.6268656716417911,
#   'f1-score': 0.6231952244144802,
#   'support': 67.0}}
